# %%
import logging
logger = logging.getLogger()
console_handler = logging.StreamHandler()
console_handler.setLevel(logging.DEBUG)
formatter = logging.Formatter("=[%(levelname)s @ %(filename)s (L=%(lineno)s) F=%(funcName)s() ]= %(message)s")
console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

# %%
import sys, os
sys.path.insert(1, os.path.join(sys.path[0], '..'))
#from generator import ExperimentConfiguration
#from generator import GeneratorConstants

# %%
RESULT_TIMING_LOGS = ["nohup_02.txt","nohup_03.txt","nohup_04.txt","nohup_08.txt","nohup_09.txt","nohup_12.txt"]
RESULT_FOLDER = "../results/"

# %%
import re

from datetime import datetime

timing_res = {}
errors = []
shapely_warnings = []
experiment_count = 0

# %%
def process_line(line):
    global experiment_count
    if line == "":
        #skip empty lines
        return True
    if "%].." in line: # Example: [ID = 11600][3.3.4.3.4][10 %]..
        # Generic progress update line - dismiss
        return None
    if "Starting experiments with config" in line: # Example: =[CRITICAL @ __main__.py (L=34) F=main() ]= Starting experiments with config ``3.3.3.3.3.3`` starting with 1001, for 100 iterations
        # Starting batch of experiments - dismiss
        return None
    if "Executing..." in line: # Example: [ID = 11600][3.3.4.3.4] Executing... @ 12-08-2023, 18:45:27
        experiment_count = experiment_count + 1
        tmp = re.findall(r'\[.*?\]', line)
        id = re.search(r'\d+', tmp[0]).group()
        cfg = tmp[1][1:-1]
        time_match = re.search(r'\d{2}-\d{2}-\d{4}, \d{2}:\d{2}:\d{2}', line)
        timer = datetime.strptime(time_match.group(), '%d-%m-%Y, %H:%M:%S')
        timing_res[id] = {"config": cfg, "start": timer, "analyze": None, "end": None, "total_secs":None}
        #print("EX")
        #Line of experiment starting
        return None
    if "Analyzing.." in line: # Example: [ID = 21401][3.12.12] Analyzing.. @ 07-08-2023, 21:28:24
        #Line of experiment result analysis starting
        tmp = re.findall(r'\[.*?\]', line)
        id = re.search(r'\d+', tmp[0]).group()
        cfg = tmp[1][1:-1]
        time_match = re.search(r'\d{2}-\d{2}-\d{4}, \d{2}:\d{2}:\d{2}', line)
        timer = datetime.strptime(time_match.group(), '%d-%m-%Y, %H:%M:%S')
        if timer is None:
            print("TIMER PARSE ERROR...", line)
        timing_res[id]["analyze"] = timer

        return None
    

    if "DONE @ " in line: # Example: [ID = 11599][3.3.4.3.4] DONE @ 12-08-2023, 18:45:27
        #Finished experiment
        tmp = re.findall(r'\[.*?\]', line)
        id = re.search(r'\d+', tmp[0]).group()
        cfg = tmp[1][1:-1]
        time_match = re.search(r'\d{2}-\d{2}-\d{4}, \d{2}:\d{2}:\d{2}', line)
        timer = datetime.strptime(time_match.group(), '%d-%m-%Y, %H:%M:%S')
        timing_res[id]["end"] = timer
        if timer is None:
            print("TIMER PARSE ERROR...", line)
        timing_res[id]["total_secs"] = (timing_res[id]["end"] - timing_res[id]["start"]).total_seconds()
        
        return None
    if "ERROR - node counts don't match" in line: # Example: =[ERROR @ experiment.py (L=590) F=execute_experiment() ]= [ID = 11599][3.3.4.3.4]ERROR - node counts don't match correctly from two calculations! SHOULD ALLWAYS MATCH... RETRYING!
        tmp = re.findall(r'\[.*?\]', line)
        err = {"id": re.search(r'\d+', tmp[1]).group(), "config": tmp[2][1:-1]}
        errors.append(err)
        return None
    if "RuntimeWarning: invalid value encountered in" in line: #Example: /home/krisjanis.nesenbergs/.local/lib/python3.8/site-packages/shapely/set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
        # Error in Shapely lib....usually leads to wrong result and recalculation
        err = {"id":"shapely", "config": None}
        shapely_warnings.append(err)
        return None
    if "return lib.intersection(a, b, **kwargs)" in line: # Example: return lib.intersection(a, b, **kwargs)
        #Aniother line of shapely warning - no new info = dismiss
        return None
    if "END:" in line: # END:  3.12.12
        # End of experiment group - dismiss
        return None
    return line

# %%
iterations = 10000000
timing_res = {}
errors = []
shapely_warnings = []
experiment_count = 0
experiment_offset = 0
import pprint 
pp = pprint.PrettyPrinter(indent=4, depth=None, sort_dicts = False)

for LOG_X in RESULT_TIMING_LOGS:
    experiment_offset = experiment_count
    FULL_PATH = RESULT_FOLDER+LOG_X
    print("Processing Log", LOG_X)
    with open(FULL_PATH) as infile:
        iii=0
        for line in infile:
            if True:
                res = process_line(line)
                if res is not None:
                    print(res)
            iii=iii+1

            if iii>iterations:
                break
        print("Log",LOG_X,"contained", str(experiment_count-experiment_offset), "experiments") 
print("====================")
print("Total experiments processed:", str(experiment_count))

print("ERRORS: ", len(errors))
#pp.pprint(errors)


print("WARNINGS: ", len(shapely_warnings))
#pp.pprint(shapely_warnings)

aggr = {}
for id in timing_res:
    cfg = timing_res[id]["config"]
    if cfg not in aggr:
        aggr[cfg] = {"sum": 0.0, "cnt": 0, "max": 0.0, "min": 99999999.0, "errors": 0 }
    tim = timing_res[id]["total_secs"]
    aggr[cfg]["sum"] = aggr[cfg]["sum"] + tim
    aggr[cfg]["cnt"] = aggr[cfg]["cnt"] + 1
    if aggr[cfg]["max"]<tim:
        aggr[cfg]["max"] = tim
    if aggr[cfg]["min"]>tim:
        aggr[cfg]["min"] = tim

for conf in aggr:
    aggr[conf]["avg"] = aggr[conf]["sum"] / aggr[conf]["cnt"]

err_id = {}  
for er in errors:
    if er["id"] not in err_id:
        err_id[er["id"]] = 0
    err_id[er["id"]] = err_id[er["id"]] + 1     

    aggr[er["config"]]["errors"] = aggr[er["config"]]["errors"] + 1
# Out:
# Processing Log nohup_02.txt
# Log nohup_02.txt contained 6500 experiments
# Processing Log nohup_03.txt
# Log nohup_03.txt contained 5850 experiments
# Processing Log nohup_04.txt
# Log nohup_04.txt contained 6500 experiments
# Processing Log nohup_08.txt
# Log nohup_08.txt contained 10400 experiments
# Processing Log nohup_09.txt
# Log nohup_09.txt contained 5850 experiments
# Processing Log nohup_12.txt
# Log nohup_12.txt contained 9100 experiments
# ====================
# Total experiments processed: 44200
# ERRORS:  2698
# WARNINGS:  422

# %%
pp.pprint(aggr)
#TODO some sort of additional analysis/graphs for each aggregated config result analysis?
# Out:
# {   '3.3.3.3.3.3': {   'sum': 16731716.0,
#                        'cnt': 3400,
#                        'max': 54426.0,
#                        'min': 168.0,
#                        'errors': 491,
#                        'avg': 4921.092941176471},
#     '4.6.12.b': {   'sum': 8410902.0,
#                     'cnt': 3400,
#                     'max': 17058.0,
#                     'min': 159.0,
#                     'errors': 103,
#                     'avg': 2473.794705882353},
#     '4.6.12.a': {   'sum': 9305675.0,
#                     'cnt': 3400,
#                     'max': 19119.0,
#                     'min': 123.0,
#                     'errors': 122,
#                     'avg': 2736.9632352941176},
#     '4.8.8': {   'sum': 8305863.0,
#                  'cnt': 3400,
#                  'max': 16702.0,
#                  'min': 173.0,
#                  'errors': 108,
#                  'avg': 2442.900882352941},
#     '3.3.4.3.4': {   'sum': 14598770.0,
#                      'cnt': 3400,
#                      'max': 41999.0,
#                      'min': 145.0,
#                      'errors': 312,
#                      'avg': 4293.755882352942},
#     '3.4.6.4': {   'sum': 12101829.0,
#                    'cnt': 3400,
#                    'max': 28756.0,
#                    'min': 137.0,
#                    'errors': 183,
#                    'avg': 3559.361470588235},
#     '3.3.3.4.4': {   'sum': 14668788.0,
#                      'cnt': 3400,
#                      'max': 40609.0,
#                      'min': 142.0,
#                      'errors': 359,
#                      'avg': 4314.349411764706},
#     '3.3.3.3.6': {   'sum': 14125501.0,
#                      'cnt': 3400,
#                      'max': 39148.0,
#                      'min': 157.0,
#                      'errors': 323,
#                      'avg': 4154.559117647059},
#     '4.6.12': {   'sum': 7728485.0,
#                   'cnt': 3400,
#                   'max': 15864.0,
#                   'min': 162.0,
#                   'errors': 85,
#                   'avg': 2273.083823529412},
#     '6.6.6': {   'sum': 8930975.0,
#                  'cnt': 3400,
#                  'max': 18113.0,
#                  'min': 151.0,
#                  'errors': 95,
#                  'avg': 2626.7573529411766},
#     '4.4.4.4': {   'sum': 12519686.0,
#                    'cnt': 3400,
#                    'max': 31940.0,
#                    'min': 141.0,
#                    'errors': 237,
#                    'avg': 3682.260588235294},
#     '3.6.3.6': {   'sum': 11685893.0,
#                    'cnt': 3400,
#                    'max': 27081.0,
#                    'min': 116.0,
#                    'errors': 191,
#                    'avg': 3437.0273529411766},
#     '3.12.12': {   'sum': 6534690.0,
#                    'cnt': 3400,
#                    'max': 13324.0,
#                    'min': 166.0,
#                    'errors': 89,
#                    'avg': 1921.9676470588236}}

# %%
#pp.pprint(err_cfg)

for eid in err_id:
    #Specific configurations, that got more than 1 error, and thus might be interesting...
    if err_id[eid]>1:
        print("ERR", eid, "=",err_id[eid], "LOG total seconds:", timing_res[eid]["total_secs"])

#pp.pprint(err_id)
# Out:
# ERR 41816 = 2 LOG total seconds: 299.0
# ERR 41818 = 2 LOG total seconds: 343.0
# ERR 18215 = 2 LOG total seconds: 778.0
# ERR 25017 = 2 LOG total seconds: 380.0
# ERR 25018 = 2 LOG total seconds: 456.0
# ERR 4617 = 4 LOG total seconds: 580.0
# ERR 42040 = 2 LOG total seconds: 422.0
# ERR 8017 = 6 LOG total seconds: 597.0
# ERR 11417 = 2 LOG total seconds: 471.0
# ERR 8020 = 3 LOG total seconds: 563.0
# ERR 1217 = 2 LOG total seconds: 478.0
# ERR 38657 = 2 LOG total seconds: 331.0
# ERR 18439 = 2 LOG total seconds: 464.0
# ERR 4636 = 2 LOG total seconds: 429.0
# ERR 11239 = 2 LOG total seconds: 533.0
# ERR 21699 = 2 LOG total seconds: 344.0
# ERR 11439 = 2 LOG total seconds: 555.0
# ERR 1236 = 3 LOG total seconds: 517.0
# ERR 1239 = 2 LOG total seconds: 496.0
# ERR 4460 = 2 LOG total seconds: 465.0
# ERR 1440 = 2 LOG total seconds: 506.0
# ERR 38560 = 2 LOG total seconds: 463.0
# ERR 4852 = 2 LOG total seconds: 867.0
# ERR 11339 = 2 LOG total seconds: 473.0
# ERR 4477 = 2 LOG total seconds: 368.0
# ERR 1056 = 2 LOG total seconds: 436.0
# ERR 11480 = 3 LOG total seconds: 374.0
# ERR 24958 = 2 LOG total seconds: 371.0
# ERR 7959 = 2 LOG total seconds: 329.0
# ERR 4763 = 2 LOG total seconds: 7374.0
# ERR 25176 = 2 LOG total seconds: 226.0
# ERR 4582 = 2 LOG total seconds: 7777.0
# ERR 11584 = 2 LOG total seconds: 8489.0
# ERR 11585 = 3 LOG total seconds: 8382.0
# ERR 1382 = 4 LOG total seconds: 9754.0
# ERR 1385 = 3 LOG total seconds: 9806.0
# ERR 19416 = 2 LOG total seconds: 336.0
# ERR 15814 = 2 LOG total seconds: 573.0
# ERR 5806 = 2 LOG total seconds: 1675.0
# ERR 26013 = 2 LOG total seconds: 623.0
# ERR 15819 = 2 LOG total seconds: 393.0
# ERR 26218 = 2 LOG total seconds: 347.0
# ERR 26219 = 2 LOG total seconds: 401.0
# ERR 43232 = 2 LOG total seconds: 573.0
# ERR 5620 = 2 LOG total seconds: 558.0
# ERR 5818 = 2 LOG total seconds: 491.0
# ERR 9213 = 3 LOG total seconds: 963.0
# ERR 12616 = 2 LOG total seconds: 516.0
# ERR 12618 = 2 LOG total seconds: 581.0
# ERR 12619 = 2 LOG total seconds: 598.0
# ERR 9216 = 2 LOG total seconds: 468.0
# ERR 2216 = 2 LOG total seconds: 488.0
# ERR 2420 = 2 LOG total seconds: 599.0
# ERR 19238 = 2 LOG total seconds: 495.0
# ERR 26037 = 2 LOG total seconds: 433.0
# ERR 26317 = 2 LOG total seconds: 581.0
# ERR 5837 = 4 LOG total seconds: 590.0
# ERR 12631 = 2 LOG total seconds: 974.0
# ERR 5916 = 2 LOG total seconds: 636.0
# ERR 9037 = 2 LOG total seconds: 524.0
# ERR 9235 = 2 LOG total seconds: 1055.0
# ERR 9240 = 3 LOG total seconds: 607.0
# ERR 16048 = 2 LOG total seconds: 2261.0
# ERR 15859 = 2 LOG total seconds: 481.0
# ERR 2436 = 2 LOG total seconds: 519.0
# ERR 26256 = 2 LOG total seconds: 424.0
# ERR 2314 = 2 LOG total seconds: 1907.0
# ERR 16918 = 2 LOG total seconds: 644.0
# ERR 5657 = 2 LOG total seconds: 443.0
# ERR 5660 = 2 LOG total seconds: 528.0
# ERR 33159 = 3 LOG total seconds: 455.0
# ERR 9256 = 2 LOG total seconds: 430.0
# ERR 2449 = 2 LOG total seconds: 3231.0
# ERR 2455 = 3 LOG total seconds: 1088.0
# ERR 5739 = 2 LOG total seconds: 636.0
# ERR 5938 = 4 LOG total seconds: 640.0
# ERR 16100 = 5 LOG total seconds: 466.0
# ERR 12479 = 2 LOG total seconds: 475.0
# ERR 39976 = 3 LOG total seconds: 331.0
# ERR 26351 = 2 LOG total seconds: 1018.0
# ERR 2335 = 2 LOG total seconds: 1354.0
# ERR 2473 = 2 LOG total seconds: 871.0
# ERR 2278 = 2 LOG total seconds: 401.0
# ERR 5697 = 2 LOG total seconds: 365.0
# ERR 12693 = 2 LOG total seconds: 700.0
# ERR 12753 = 2 LOG total seconds: 629.0
# ERR 2296 = 3 LOG total seconds: 208.0
# ERR 2556 = 2 LOG total seconds: 271.0
# ERR 26391 = 2 LOG total seconds: 602.0
# ERR 2384 = 2 LOG total seconds: 11535.0
# ERR 21018 = 2 LOG total seconds: 343.0
# ERR 4020 = 2 LOG total seconds: 570.0
# ERR 7419 = 2 LOG total seconds: 573.0
# ERR 7616 = 3 LOG total seconds: 523.0
# ERR 17836 = 3 LOG total seconds: 476.0
# ERR 4036 = 2 LOG total seconds: 501.0
# ERR 4239 = 2 LOG total seconds: 594.0
# ERR 7437 = 3 LOG total seconds: 596.0
# ERR 7640 = 2 LOG total seconds: 629.0
# ERR 21298 = 2 LOG total seconds: 376.0
# ERR 833 = 2 LOG total seconds: 1372.0
# ERR 637 = 3 LOG total seconds: 651.0
# ERR 24660 = 2 LOG total seconds: 557.0
# ERR 920 = 2 LOG total seconds: 908.0
# ERR 41697 = 2 LOG total seconds: 371.0
# ERR 4260 = 2 LOG total seconds: 522.0
# ERR 7658 = 2 LOG total seconds: 539.0
# ERR 4139 = 2 LOG total seconds: 680.0
# ERR 11133 = 2 LOG total seconds: 1606.0
# ERR 4271 = 2 LOG total seconds: 978.0
# ERR 7679 = 2 LOG total seconds: 489.0
# ERR 14159 = 2 LOG total seconds: 571.0
# ERR 38379 = 2 LOG total seconds: 466.0
# ERR 14560 = 3 LOG total seconds: 547.0
# ERR 24578 = 2 LOG total seconds: 239.0
# ERR 700 = 4 LOG total seconds: 261.0
# ERR 763 = 3 LOG total seconds: 12562.0
# ERR 956 = 2 LOG total seconds: 293.0
# ERR 959 = 2 LOG total seconds: 325.0
# ERR 4383 = 3 LOG total seconds: 10656.0
# ERR 11181 = 3 LOG total seconds: 11476.0
# ERR 4182 = 2 LOG total seconds: 10489.0
# ERR 7782 = 2 LOG total seconds: 11199.0
# ERR 10985 = 2 LOG total seconds: 11535.0
# ERR 964 = 2 LOG total seconds: 12702.0
# ERR 781 = 2 LOG total seconds: 14607.0
# ERR 11000 = 2 LOG total seconds: 331.0
# ERR 783 = 3 LOG total seconds: 13824.0
# ERR 11197 = 3 LOG total seconds: 289.0
# ERR 581 = 2 LOG total seconds: 12939.0
# ERR 982 = 3 LOG total seconds: 13694.0
# ERR 584 = 3 LOG total seconds: 13044.0
# ERR 985 = 3 LOG total seconds: 13294.0
# ERR 997 = 2 LOG total seconds: 348.0
# ERR 31016 = 2 LOG total seconds: 337.0
# ERR 37416 = 2 LOG total seconds: 347.0
# ERR 13617 = 2 LOG total seconds: 413.0
# ERR 24016 = 2 LOG total seconds: 404.0
# ERR 24218 = 2 LOG total seconds: 501.0
# ERR 3620 = 2 LOG total seconds: 562.0
# ERR 7218 = 4 LOG total seconds: 582.0
# ERR 34119 = 2 LOG total seconds: 492.0
# ERR 13916 = 2 LOG total seconds: 513.0
# ERR 41059 = 4 LOG total seconds: 469.0
# ERR 3511 = 3 LOG total seconds: 1547.0
# ERR 3839 = 3 LOG total seconds: 467.0
# ERR 10439 = 2 LOG total seconds: 585.0
# ERR 437 = 3 LOG total seconds: 577.0
# ERR 117 = 2 LOG total seconds: 759.0
# ERR 17077 = 2 LOG total seconds: 325.0
# ERR 10457 = 2 LOG total seconds: 472.0
# ERR 6858 = 3 LOG total seconds: 475.0
# ERR 24274 = 2 LOG total seconds: 716.0
# ERR 6938 = 2 LOG total seconds: 624.0
# ERR 3476 = 2 LOG total seconds: 377.0
# ERR 3480 = 2 LOG total seconds: 427.0
# ERR 7277 = 2 LOG total seconds: 351.0
# ERR 7278 = 2 LOG total seconds: 370.0
# ERR 23895 = 2 LOG total seconds: 691.0
# ERR 136 = 2 LOG total seconds: 436.0
# ERR 3497 = 2 LOG total seconds: 283.0
# ERR 74 = 2 LOG total seconds: 681.0
# ERR 477 = 2 LOG total seconds: 311.0
# ERR 22019 = 2 LOG total seconds: 263.0
# ERR 42414 = 2 LOG total seconds: 431.0
# ERR 42417 = 3 LOG total seconds: 259.0
# ERR 15217 = 3 LOG total seconds: 270.0
# ERR 25417 = 2 LOG total seconds: 254.0
# ERR 5019 = 3 LOG total seconds: 316.0
# ERR 8417 = 2 LOG total seconds: 296.0
# ERR 11818 = 2 LOG total seconds: 342.0
# ERR 8420 = 3 LOG total seconds: 385.0
# ERR 1616 = 2 LOG total seconds: 436.0
# ERR 1620 = 5 LOG total seconds: 604.0
# ERR 18636 = 2 LOG total seconds: 368.0
# ERR 5033 = 2 LOG total seconds: 762.0
# ERR 11840 = 3 LOG total seconds: 586.0
# ERR 18656 = 2 LOG total seconds: 326.0
# ERR 1638 = 2 LOG total seconds: 473.0
# ERR 4918 = 2 LOG total seconds: 668.0
# ERR 100 = 2 LOG total seconds: 582.0
# ERR 5060 = 2 LOG total seconds: 316.0
# ERR 8453 = 2 LOG total seconds: 770.0
# ERR 15267 = 2 LOG total seconds: 1868.0
# ERR 15276 = 2 LOG total seconds: 310.0
# ERR 160 = 2 LOG total seconds: 788.0
# ERR 32156 = 2 LOG total seconds: 295.0
# ERR 25493 = 2 LOG total seconds: 649.0
# ERR 10381 = 3 LOG total seconds: 21440.0
# ERR 4936 = 2 LOG total seconds: 384.0
# ERR 3584 = 3 LOG total seconds: 17855.0
# ERR 10383 = 2 LOG total seconds: 18170.0
# ERR 10584 = 2 LOG total seconds: 17706.0
# ERR 10384 = 3 LOG total seconds: 17592.0
# ERR 1698 = 2 LOG total seconds: 320.0
# ERR 181 = 2 LOG total seconds: 16320.0
# ERR 7199 = 2 LOG total seconds: 475.0
# ERR 10398 = 2 LOG total seconds: 352.0
# ERR 383 = 3 LOG total seconds: 11585.0
# ERR 384 = 3 LOG total seconds: 11807.0
# ERR 185 = 3 LOG total seconds: 11433.0
# ERR 13384 = 3 LOG total seconds: 9119.0
# ERR 3182 = 2 LOG total seconds: 11227.0
# ERR 23016 = 2 LOG total seconds: 247.0
# ERR 19820 = 2 LOG total seconds: 444.0
# ERR 16414 = 2 LOG total seconds: 588.0
# ERR 16418 = 3 LOG total seconds: 362.0
# ERR 6218 = 2 LOG total seconds: 410.0
# ERR 6219 = 3 LOG total seconds: 456.0
# ERR 9412 = 4 LOG total seconds: 979.0
# ERR 13018 = 3 LOG total seconds: 522.0
# ERR 9417 = 3 LOG total seconds: 510.0
# ERR 9619 = 2 LOG total seconds: 567.0
# ERR 12818 = 2 LOG total seconds: 575.0
# ERR 40233 = 2 LOG total seconds: 654.0
# ERR 2611 = 2 LOG total seconds: 1083.0
# ERR 2617 = 2 LOG total seconds: 603.0
# ERR 2817 = 5 LOG total seconds: 613.0
# ERR 2619 = 2 LOG total seconds: 584.0
# ERR 19839 = 2 LOG total seconds: 504.0
# ERR 16236 = 2 LOG total seconds: 458.0
# ERR 16518 = 2 LOG total seconds: 592.0
# ERR 19719 = 2 LOG total seconds: 604.0
# ERR 6233 = 3 LOG total seconds: 1057.0
# ERR 6240 = 2 LOG total seconds: 576.0
# ERR 6037 = 2 LOG total seconds: 549.0
# ERR 6316 = 2 LOG total seconds: 590.0
# ERR 9436 = 3 LOG total seconds: 519.0
# ERR 13118 = 2 LOG total seconds: 742.0
# ERR 43679 = 2 LOG total seconds: 429.0
# ERR 33279 = 3 LOG total seconds: 497.0
# ERR 2832 = 2 LOG total seconds: 1173.0
# ERR 26459 = 2 LOG total seconds: 552.0
# ERR 13058 = 2 LOG total seconds: 513.0
# ERR 9459 = 2 LOG total seconds: 488.0
# ERR 2859 = 2 LOG total seconds: 530.0
# ERR 13140 = 2 LOG total seconds: 571.0
# ERR 23196 = 3 LOG total seconds: 324.0
# ERR 9677 = 3 LOG total seconds: 431.0
# ERR 26498 = 2 LOG total seconds: 405.0
# ERR 26499 = 3 LOG total seconds: 436.0
# ERR 9497 = 2 LOG total seconds: 323.0
# ERR 6783 = 2 LOG total seconds: 22084.0
# ERR 2900 = 2 LOG total seconds: 218.0
# ERR 6784 = 2 LOG total seconds: 16631.0
# ERR 2696 = 3 LOG total seconds: 206.0
# ERR 2957 = 3 LOG total seconds: 293.0
# ERR 2959 = 2 LOG total seconds: 292.0
# ERR 26576 = 2 LOG total seconds: 213.0
# ERR 2978 = 2 LOG total seconds: 307.0
# ERR 9798 = 3 LOG total seconds: 273.0
# ERR 29220 = 2 LOG total seconds: 455.0
# ERR 32617 = 2 LOG total seconds: 338.0
# ERR 18818 = 3 LOG total seconds: 459.0
# ERR 18819 = 2 LOG total seconds: 429.0
# ERR 15618 = 2 LOG total seconds: 428.0
# ERR 12008 = 2 LOG total seconds: 2262.0
# ERR 5417 = 2 LOG total seconds: 507.0
# ERR 12214 = 2 LOG total seconds: 882.0
# ERR 12015 = 2 LOG total seconds: 923.0
# ERR 42920 = 2 LOG total seconds: 518.0
# ERR 8615 = 2 LOG total seconds: 927.0
# ERR 12219 = 2 LOG total seconds: 541.0
# ERR 8820 = 2 LOG total seconds: 569.0
# ERR 2010 = 2 LOG total seconds: 2759.0
# ERR 2019 = 5 LOG total seconds: 665.0
# ERR 19036 = 2 LOG total seconds: 408.0
# ERR 19039 = 2 LOG total seconds: 513.0
# ERR 25631 = 3 LOG total seconds: 829.0
# ERR 25718 = 2 LOG total seconds: 643.0
# ERR 39260 = 2 LOG total seconds: 549.0
# ERR 5433 = 2 LOG total seconds: 998.0
# ERR 32539 = 2 LOG total seconds: 522.0
# ERR 12040 = 2 LOG total seconds: 552.0
# ERR 8838 = 4 LOG total seconds: 672.0
# ERR 8839 = 2 LOG total seconds: 585.0
# ERR 8516 = 2 LOG total seconds: 645.0
# ERR 8840 = 2 LOG total seconds: 602.0
# ERR 8520 = 3 LOG total seconds: 779.0
# ERR 42879 = 2 LOG total seconds: 427.0
# ERR 12120 = 2 LOG total seconds: 776.0
# ERR 8919 = 2 LOG total seconds: 769.0
# ERR 8920 = 2 LOG total seconds: 750.0
# ERR 18857 = 2 LOG total seconds: 459.0
# ERR 2039 = 2 LOG total seconds: 598.0
# ERR 25660 = 2 LOG total seconds: 509.0
# ERR 1718 = 2 LOG total seconds: 814.0
# ERR 2117 = 2 LOG total seconds: 821.0
# ERR 1920 = 2 LOG total seconds: 818.0
# ERR 32497 = 2 LOG total seconds: 331.0
# ERR 42898 = 2 LOG total seconds: 401.0
# ERR 5260 = 2 LOG total seconds: 505.0
# ERR 18939 = 4 LOG total seconds: 613.0
# ERR 12251 = 2 LOG total seconds: 967.0
# ERR 12060 = 2 LOG total seconds: 509.0
# ERR 25537 = 3 LOG total seconds: 534.0
# ERR 25677 = 3 LOG total seconds: 414.0
# ERR 2057 = 2 LOG total seconds: 491.0
# ERR 1860 = 3 LOG total seconds: 596.0
# ERR 5339 = 2 LOG total seconds: 634.0
# ERR 19096 = 2 LOG total seconds: 396.0
# ERR 32375 = 2 LOG total seconds: 948.0
# ERR 32579 = 2 LOG total seconds: 468.0
# ERR 12338 = 2 LOG total seconds: 588.0
# ERR 12078 = 2 LOG total seconds: 418.0
# ERR 8677 = 2 LOG total seconds: 379.0
# ERR 8680 = 3 LOG total seconds: 503.0
# ERR 15358 = 2 LOG total seconds: 431.0
# ERR 1936 = 2 LOG total seconds: 580.0
# ERR 25560 = 3 LOG total seconds: 525.0
# ERR 8899 = 2 LOG total seconds: 482.0
# ERR 8900 = 2 LOG total seconds: 495.0
# ERR 18773 = 2 LOG total seconds: 1275.0
# ERR 20213 = 2 LOG total seconds: 644.0
# ERR 8956 = 2 LOG total seconds: 622.0
# ERR 8957 = 3 LOG total seconds: 651.0
# ERR 3215 = 2 LOG total seconds: 906.0
# ERR 2099 = 2 LOG total seconds: 523.0
# ERR 9839 = 3 LOG total seconds: 448.0
# ERR 1900 = 3 LOG total seconds: 604.0
# ERR 33678 = 2 LOG total seconds: 275.0
# ERR 3034 = 2 LOG total seconds: 999.0
# ERR 3040 = 2 LOG total seconds: 515.0
# ERR 3237 = 2 LOG total seconds: 419.0
# ERR 5571 = 2 LOG total seconds: 1255.0
# ERR 9877 = 2 LOG total seconds: 180.0
# ERR 3079 = 2 LOG total seconds: 218.0
# ERR 1971 = 2 LOG total seconds: 829.0
# ERR 8598 = 2 LOG total seconds: 299.0
# ERR 2182 = 2 LOG total seconds: 12595.0
# ERR 8799 = 3 LOG total seconds: 314.0
# ERR 1784 = 2 LOG total seconds: 11427.0

# %%
total_time = 0.0
for ind in aggr:
    total_time = total_time + aggr[ind]['sum']
print(total_time)
# Out:
# 145648773.0

# %%
print("Total time in seconds:", total_time)
# Out:
# Total time in seconds: 145648773.0

# %%
print("Total time in minutes:", total_time/60)
# Out:
# Total time in minutes: 2427479.55

# %%
print("Total time in hours:", total_time/3600)
# Out:
# Total time in hours: 40457.9925

# %%
print("Total time in days:", (total_time/3600)/24)
# Out:
# Total time in days: 1685.7496875

# %%
print("Total time in years:", ((total_time/3600)/24)/365.35)
# Out:
# Total time in years: 4.61406784590119

# %%
print("Total time on 32 cores in days:", ((total_time/3600)/24)/32)
# Out:
# Total time on 32 cores in days: 52.679677734375

# %%
print("Total time on 6 servers with 32 cores in days:", ((total_time/3600)/24)/(32*6))
# Out:
# Total time on 6 servers with 32 cores in days: 8.779946289062499

# %%
#max time
max_time = aggr['3.3.3.3.3.3']['max']

# %%
print("Max time for one calculation in hours:", max_time/3600)
# Out:
# Max time for one calculation in hours: 15.118333333333334

# %%
#ACTUAL TIME:
#02 x 6500: 07-08-2023, 20:53:54 => 13-08-2023, 08:19:46 = 5 days, 11 hours, 25 minutes, 52 seconds (473152 seconds)
#03 x 5850: 09-08-2023, 06:19:05 => 15-08-2023, 15:28:06 = 6 days, 9 hours, 9 minutes, 1 seconds (551341 seconds)
#04 x 6500: 07-08-2023, 10:28:36 => 15-08-2023, 06:36:11 = 7 days, 20 hours, 7 minutes, 35 seconds (677255 seconds)
#08 x 10400: 05-08-2023, 18:10:22 => 15-08-2023, 10:01:54 = 9 days, 15 hours, 51 minutes, 32 seconds (834692 seconds)
#09 x 5850: 09-08-2023, 06:20:11 => 15-08-2023, 13:17:23 = 6 days, 6 hours, 57 minutes, 12 seconds (543432 seconds)
#12 x 9100: 05-08-2023, 15:09:45 => 13-08-2023, 11:57:37 = 7 days, 20 hours, 47 minutes, 52 seconds (679672 seconds)

# Longest time:
# 05-08-2023, 15:09:45 => 15-08-2023, 15:28:06 = 10 days, 0 hours, 17 minutes, 44 seconds (865064 seconds)
# instead of theoretical 8 days, 18 hours, 43 minutes, 8 seconds
# thus overhead over theoretical due to bad planning = 1 day, 5 hours, 34 minutes, 36 seconds
